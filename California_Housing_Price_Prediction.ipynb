# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ca_df = pd.read_excel('California_housing.xlsx')

# %%
ca_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income ocean_proximity  median_house_value
# 0         322         126         8.3252        NEAR BAY              452600
# 1        2401        1138         8.3014        NEAR BAY              358500
# 2         496         177         7.2574        NEAR BAY              352100
# 3         558         219         5.6431        NEAR BAY              341300
# 4         565         259         3.8462        NEAR BAY              342200

# %%
ca_df.shape
# Out:
# (20640, 10)

# %%
ca_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   ocean_proximity     20640 non-null  object
#  9   median_house_value  20640 non-null  int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
ca_df.isnull().sum()
# Missing records exist for total_bedrooms
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# ocean_proximity         0
# median_house_value      0
# dtype: int64

# %%
ca_df['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# ## Encoding categorical data to numerical data

# %%
ca_encd = pd.get_dummies(ca_df,columns=['ocean_proximity'])
ca_encd.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
# 5    -122.25     37.85                  52          919           213.0
# 6    -122.25     37.84                  52         2535           489.0
# 7    -122.25     37.84                  52         3104           687.0
# 8    -122.26     37.84                  42         2555           665.0
# 9    -122.25     37.84                  52         3549           707.0
#
#    population  households  median_income  median_house_value  \
# 0         322         126         8.3252              452600
# ...

# %%
ca_df = ca_encd
ca_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value  \
# 0         322         126         8.3252              452600
# 1        2401        1138         8.3014              358500
# 2         496         177         7.2574              352100
# 3         558         219         5.6431              341300
# 4         565         259         3.8462              342200
#
#    ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  ocean_proximity_ISLAND  \
# 0                          0                       0                       0
# ...

# %%
ca_df.describe(include='all')
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
ca_df.hist(bins=50,figsize=(20,10));

# %% [markdown]
# # EDA for Location

# %%
# Since Latitude and Longitude are given, household spread across the region should be a important factor
plt.figure(figsize=(10,10))
plt.scatter(ca_df['longitude'],ca_df['latitude'],alpha=0.5)
# Taking alpha as 0.5 to look at high density household areas
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Household spread across the CA map")
# Out:
# Text(0.5, 1.0, 'Household spread across the CA map')

# %%
plt.figure(figsize=(10,10))

# Getting the CA map
map = plt.imread('California.png')
plt.imshow(map, extent=[-124.35,-114.2,32.54,42.95])

#Combining scatter plot with map
plt.scatter(ca_df['longitude'],ca_df['latitude'],alpha=0.5, c=ca_df['median_house_value'])
plt.colorbar()

# %% [markdown]
# ## Missing value treatment

# %%
ca_df['total_bedrooms'].hist(bins=50,range=(0,7000))
# Out:
# <AxesSubplot:>

# %%
# Filling the missing values with the mean
ca_df['total_bedrooms'] = np.where(ca_df['total_bedrooms'].isnull(),ca_df['total_bedrooms'].mean(),ca_df['total_bedrooms'])

# %%
ca_df.isnull().sum()
# Out:
# longitude                     0
# latitude                      0
# housing_median_age            0
# total_rooms                   0
# total_bedrooms                0
# population                    0
# households                    0
# median_income                 0
# median_house_value            0
# ocean_proximity_<1H OCEAN     0
# ocean_proximity_INLAND        0
# ocean_proximity_ISLAND        0
# ocean_proximity_NEAR BAY      0
# ocean_proximity_NEAR OCEAN    0
# dtype: int64

# %%
# Extracting (X) and (Y) from the dataset
y = ca_df['median_house_value']
x = ca_df.drop('median_house_value',axis=1)

# %%
print(y)
x.head()
# Out:
# 0        452600
# 1        358500
# 2        352100
# 3        341300
# 4        342200
#           ...
# 20635     78100
# 20636     77100
# 20637     92300
# 20638     84700
# 20639     89400
# Name: median_house_value, Length: 20640, dtype: int64
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  ocean_proximity_<1H OCEAN  \
# 0         322         126         8.3252                          0
# 1        2401        1138         8.3014                          0
# 2         496         177         7.2574                          0
# ...

# %% [markdown]
# ## Splitting data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,train_size=0.8,random_state=10)

# %%
print("x train and test :\n",xtrain.shape,'\n',xtest.shape,"\ny train and test :\n",ytrain.shape,'\n',ytest.shape)
# Out:
# x train and test :
#  (16512, 13)
#  (4128, 13)
# y train and test :
#  (16512,)
#  (4128,)

# %% [markdown]
# ## Standardizing dependent variables
# to make their weightage/units same

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
xtrain_sc = sc.fit_transform(xtrain)
xtest_sc = sc.transform(xtest)  
# Only transforming on the basis of fit() done in train data so that we have same mean and stdev throughout

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lin_model = LinearRegression(fit_intercept=True,copy_X=True)

# %%
lin_model.fit(xtrain_sc,ytrain)
# Out:
# LinearRegression()

# %%
# Coefficients
lin_model.coef_
# Out:
# array([-54476.10287485, -55321.43074371,  13469.23029665, -10818.28237954,
#         31309.17719571, -41542.83609617,  26178.27524951,  73610.06677446,
#          5978.05735475, -12364.82826787,   2927.29149078,   2669.92386004,
#          5685.20676993])

# %%
# Prediction 
ypred = lin_model.predict(xtest_sc)

# %%
ypred
# Out:
# array([276313.4461001 , 281737.57791607, 274318.57208302, ...,
#        229658.05582562, 117362.84467916, 378223.86712439])

# %% [markdown]
# ## RMSE

# %%
err = ytest - ypred

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(ytest,ypred)
import math
math.sqrt(mse)
# Out:
# 69457.92755247482

# %% [markdown]
# # Linear Regression with one independent variable

# %%
xtrain.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12346    -116.52     33.82                  21        10227          2315.0
# 19326    -122.94     38.50                  46         2280           492.0
# 16824    -122.49     37.63                  31         3109           621.0
# 6869     -118.11     34.06                  16         2416           565.0
# 16677    -120.66     35.13                  41         2666           751.0
#
#        population  households  median_income  ocean_proximity_<1H OCEAN  \
# 12346        3623        1734         2.5212                          0
# 19326         807         366         2.6316                          1
# 16824        1472         618         5.1550                          0
# 6869         1750         514         2.8229                          1
# 16677         940         507         1.9653                          1
#
#        ocean_proximity_INLAND  ocean_proximity_ISLAND  \
# ...

# %%
xtrain.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
#        'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY',
#        'ocean_proximity_NEAR OCEAN'],
#       dtype='object')

# %%
xtrain_inc = xtrain.drop(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
       'total_bedrooms', 'population', 'households',
       'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
       'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY',
       'ocean_proximity_NEAR OCEAN'],axis=1)

xtrain_inc.head()
# Out:
#        median_income
# 12346         2.5212
# 19326         2.6316
# 16824         5.1550
# 6869          2.8229
# 16677         1.9653

# %%
xtest.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20303    -119.18     34.16                  12          460           101.0
# 16966    -122.31     37.55                  27         3931           933.0
# 10623    -117.77     33.67                  12         4329          1068.0
# 6146     -117.95     34.11                  29         1986           448.0
# 2208     -119.87     36.81                   6         1891           341.0
#
#        population  households  median_income  ocean_proximity_<1H OCEAN  \
# 20303         405         103         5.2783                          0
# 16966        1877         851         3.9722                          0
# 10623        1913         978         4.5094                          1
# 6146         2013         432         3.1034                          0
# 2208          969         330         4.6726                          0
#
#        ocean_proximity_INLAND  ocean_proximity_ISLAND  \
# ...

# %%
xtest_inc = xtest.drop(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
       'total_bedrooms', 'population', 'households',
       'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
       'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY',
       'ocean_proximity_NEAR OCEAN'],axis=1)
xtest_inc.head(10)
# Out:
#        median_income
# 20303         5.2783
# 16966         3.9722
# 10623         4.5094
# 6146          3.1034
# 2208          4.6726
# 1982          3.0565
# 14883         3.5583
# 7620          3.8125
# 16191         1.3191
# 17001         6.5948

# %%
lm = LinearRegression(fit_intercept=True,copy_X=True)

# %%
lm.fit(xtrain_inc,ytrain)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([41808.4092128])

# %%
# Prediction
ypred = lm.predict(xtest_inc)
ypred
# Out:
# array([265614.76463655, 211008.80136372, 233468.27879283, ...,
#        211222.0242507 ,  83973.94997063, 372610.84549394])

# %%
ytest
# Out:
# 20303    167400
# 16966    354100
# 10623    160200
# 6146     140800
# 2208     107800
#           ...
# 3263     106300
# 11694    393700
# 1729     131300
# 5087      92300
# 6581     500001
# Name: median_house_value, Length: 4128, dtype: int64

# %%
# Plot for model on training and test datasets

fig,axs = plt.subplots(ncols=2,sharex=False,sharey=False, figsize=(15,5))

import seaborn as sns

axs[0].set(title='Train data')
axs[1].set(title='Test data')
sns.regplot(x=xtrain_inc,y=ytrain,scatter_kws={"color": "blue",'alpha':0.3}, line_kws={"color": "red",'alpha':0.5}, ax=axs[0]);
sns.regplot(x=xtest_inc,y=ytest,scatter_kws={"color": "green",'alpha':0.3}, line_kws={"color": "yellow",'alpha':0.5}, ax=axs[1]);

# %%
# Actual Vs Predicted Housing Price Plot
fig = plt.figure(figsize=(25,8))

  # Actual vs Predicted scatter plot for Test data
plt.scatter(ytest,ypred,marker="o")
  
   # Scatter plot for model 
plt.scatter(ytrain,lm.predict(xtrain_inc),marker="+",alpha=0.5)
plt.xlabel(" Actual median_house_value")
plt.ylabel(" Predicted median_house_value")
# Out:
# Text(0, 0.5, ' Predicted median_house_value')
